# %%
import pandas as pd
import numpy as np

# %%
car=pd.read_csv('used_car_dataset.csv')

# %%
car.head()
# Out:
#                                             car_name car_price_in_rupees  \
# 0  Hyundai Grand i10 Magna 1.2 Kappa VTVT [2017-2...         ₹ 4.45 Lakh
# 1                         Maruti Suzuki Alto 800 Lxi         ₹ 2.93 Lakh
# 2                            Tata Safari XZ Plus New        ₹ 22.49 Lakh
# 3                            Maruti Suzuki Ciaz ZXI+         ₹ 6.95 Lakh
# 4     Jeep Compass Sport Plus 1.4 Petrol [2019-2020]           ₹ 12 Lakh
#
#   kms_driven fuel_type       city  year_of_manufacture
# 0  22,402 km    Petrol     Mumbai                 2016
# 1  10,344 km    Petrol    Kolkata                 2019
# 2  12,999 km    Diesel  Bangalore                 2021
# 3  45,000 km    Petrol      Thane                 2016
# 4  11,193 km    Petrol    Kolkata                 2019

# %%
car.shape
# Out:
# (2105, 6)

# %%
car.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2105 entries, 0 to 2104
# Data columns (total 6 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   car_name             2105 non-null   object
#  1   car_price_in_rupees  2105 non-null   object
#  2   kms_driven           2105 non-null   object
#  3   fuel_type            2105 non-null   object
#  4   city                 2105 non-null   object
#  5   year_of_manufacture  2105 non-null   int64
# dtypes: int64(1), object(5)
# memory usage: 98.8+ KB

# %%
car['year_of_manufacture'].unique()
# Out:
# array([2016, 2019, 2021, 2017, 2013, 2018, 2007, 2022, 2014, 2020, 2015,
#        2009, 2011, 2010, 2012, 2008, 2006, 2004, 2005])

# %% [markdown]
# year has year values no non -year values
# year is in integers

# %%
car['car_price_in_rupees'].unique()
# Out:
# array(['₹ 4.45 Lakh', '₹ 2.93 Lakh', '₹ 22.49 Lakh', '₹ 6.95 Lakh',
#        '₹ 12 Lakh', '₹ 3.72 Lakh', '₹ 11.5 Lakh', '₹ 10.39 Lakh',
#        '₹ 3.75 Lakh', '₹ 4.25 Lakh', '₹ 6.75 Lakh', '₹ 4.49 Lakh',
#        '₹ 3 Lakh', '₹ 9.5 Lakh', '₹ 13.25 Lakh', '₹ 9.25 Lakh',
#        '₹ 95 Lakh', '₹ 8.71 Lakh', '₹ 3.35 Lakh', '₹ 9.88 Lakh',
#        '₹ 1.15 Crore', '₹ 11 Lakh', '₹ 9.9 Lakh', '₹ 3.45 Lakh',
#        '₹ 37.49 Lakh', '₹ 6.39 Lakh', '₹ 8.9 Lakh', '₹ 6.59 Lakh',
#        '₹ 3.92 Lakh', '₹ 8 Lakh', '₹ 7.75 Lakh', '₹ 11.52 Lakh',
#        '₹ 16.75 Lakh', '₹ 8.5 Lakh', '₹ 5.93 Lakh', '₹ 4.15 Lakh',
#        '₹ 18.5 Lakh', '₹ 2.4 Lakh', '₹ 11.99 Lakh', '₹ 8.95 Lakh',
#        '₹ 9.68 Lakh', '₹ 81 Lakh', '₹ 4.93 Lakh', '₹ 10.5 Lakh',
#        '₹ 7.85 Lakh', '₹ 38.99 Lakh', '₹ 31 Lakh', '₹ 4.85 Lakh',
#        '₹ 4.35 Lakh', '₹ 4.51 Lakh', '₹ 5.45 Lakh', '₹ 4.5 Lakh',
#        '₹ 6.81 Lakh', '₹ 3.95 Lakh', '₹ 11.43 Lakh', '₹ 23 Lakh',
# ...

# %% [markdown]
# convert rupee to int and remove rupee and lakh

# %%
car['kms_driven'].unique()
# Out:
# array(['22,402 km', '10,344 km', '12,999 km', ..., '37,622 km',
#        '64,726 km', '29,150 km'], dtype=object)

# %% [markdown]
# convert to int it is in objects remove commas

# %%
car['fuel_type'].unique()
# Out:
# array(['Petrol', 'Diesel', 'Diesel + 1', 'Electric', 'CNG', 'Petrol + 1',
#        'Hybrid', 'LPG'], dtype=object)

# %% [markdown]
# in carname keep only first 3 words

# %% [markdown]
# **CLEANING**

# %%
backup=car.copy()

# %%
car=car[car['year_of_manufacture'].apply(lambda x: pd.to_numeric(x, errors='coerce')).notnull()]

# %%
car['car_price_in_rupees'] = car['car_price_in_rupees'].astype(str)
car['car_price_in_rupees'] = car['car_price_in_rupees'].str.replace('₹', '')
car['car_price_in_rupees'] = car['car_price_in_rupees'].str.replace('Lakh', '')
car['car_price_in_rupees'] = pd.to_numeric(car['car_price_in_rupees'], errors='coerce') * 100000
car['car_price_in_rupees']
# Out:
# 0        445000.0
# 1        293000.0
# 2       2249000.0
# 3        695000.0
# 4       1200000.0
#           ...
# 2100     360000.0
# 2101    2200000.0
# 2102     838000.0
# 2103     675000.0
# 2104     876000.0
# Name: car_price_in_rupees, Length: 2105, dtype: float64

# %%
car.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2105 entries, 0 to 2104
# Data columns (total 6 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   car_name             2105 non-null   object
#  1   car_price_in_rupees  2098 non-null   float64
#  2   kms_driven           2105 non-null   object
#  3   fuel_type            2105 non-null   object
#  4   city                 2105 non-null   object
#  5   year_of_manufacture  2105 non-null   int64
# dtypes: float64(1), int64(1), object(4)
# memory usage: 115.1+ KB

# %%
# Replace NaN with 0 and convert to integers
car['car_price_in_rupees'] = car['car_price_in_rupees'].fillna(0).astype(int)

# %%
car.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2105 entries, 0 to 2104
# Data columns (total 6 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   car_name             2105 non-null   object
#  1   car_price_in_rupees  2105 non-null   int64
#  2   kms_driven           2105 non-null   object
#  3   fuel_type            2105 non-null   object
#  4   city                 2105 non-null   object
#  5   year_of_manufacture  2105 non-null   int64
# dtypes: int64(2), object(4)
# memory usage: 115.1+ KB

# %%
car['kms_driven'] = car['kms_driven'].astype(str)
car['kms_driven'] = car['kms_driven'].str.split(' ').str.get(0).str.replace(',', '')

# %%
car['kms_driven']=car['kms_driven'].astype(int)

# %%
car.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2105 entries, 0 to 2104
# Data columns (total 6 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   car_name             2105 non-null   object
#  1   car_price_in_rupees  2105 non-null   int64
#  2   kms_driven           2105 non-null   int64
#  3   fuel_type            2105 non-null   object
#  4   city                 2105 non-null   object
#  5   year_of_manufacture  2105 non-null   int64
# dtypes: int64(3), object(3)
# memory usage: 115.1+ KB

# %%
car[car['fuel_type'].isna()]
# Out:
# Empty DataFrame
# Columns: [car_name, car_price_in_rupees, kms_driven, fuel_type, city, year_of_manufacture]
# Index: []

# %% [markdown]
# checking if fuel type is null

# %%
car['car_name']=car['car_name'].str.split(' ').str.slice(0,3).str.join(' ')

# %%
car.reset_index(drop=True)
# Out:
#                     car_name  car_price_in_rupees  kms_driven fuel_type  \
# 0          Hyundai Grand i10               445000       22402    Petrol
# 1         Maruti Suzuki Alto               293000       10344    Petrol
# 2             Tata Safari XZ              2249000       12999    Diesel
# 3         Maruti Suzuki Ciaz               695000       45000    Petrol
# 4         Jeep Compass Sport              1200000       11193    Petrol
# ...                      ...                  ...         ...       ...
# 2100   Ford Figo Titanium1.5               360000       42158    Diesel
# 2101  MINI Cooper Countryman              2200000       68862    Diesel
# 2102       Hyundai Verna 1.6               838000       37622    Petrol
# 2103      Maruti Suzuki Ciaz               675000       64726    Petrol
# 2104       Hyundai Verna 1.6               876000       29150    Petrol
#
#            city  year_of_manufacture
# 0        Mumbai                 2016
# ...

# %% [markdown]
# **CLEANED**

# %%
car.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2105 entries, 0 to 2104
# Data columns (total 6 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   car_name             2105 non-null   object
#  1   car_price_in_rupees  2105 non-null   int64
#  2   kms_driven           2105 non-null   int64
#  3   fuel_type            2105 non-null   object
#  4   city                 2105 non-null   object
#  5   year_of_manufacture  2105 non-null   int64
# dtypes: int64(3), object(3)
# memory usage: 115.1+ KB

# %%
car.describe()
# Out:
#        car_price_in_rupees    kms_driven  year_of_manufacture
# count         2.105000e+03  2.105000e+03          2105.000000
# mean          1.098663e+06  4.830131e+04          2017.022803
# std           1.186164e+06  8.372047e+04             2.818066
# min           0.000000e+00  6.400000e+01          2004.000000
# 25%           4.750000e+05  2.499300e+04          2015.000000
# 50%           6.950000e+05  4.282500e+04          2017.000000
# 75%           1.150000e+06  6.300000e+04          2019.000000
# max           9.500000e+06  3.600000e+06          2022.000000

# %%
car[car['car_price_in_rupees']>6e6]
# Out:
#                      car_name  car_price_in_rupees  kms_driven fuel_type  \
# 17      Mercedes-Benz EQC 400              9500000        3200  Electric
# 42      Mercedes-Benz EQC 400              8100000       21500  Electric
# 63      Mercedes-Benz GLC 200              6600000       16785    Petrol
# 64    Mercedes-Benz E-Class E              6898999        3999    Petrol
# 212   Mercedes-Benz E-Class E              6175000       19070    Diesel
# 270     Mercedes-Benz GLS 350              6800000       88000    Diesel
# 300     Porsche Cayenne Turbo              7856999       12000    Petrol
# 308          Land Rover Range              7700000        5600    Petrol
# 336   Mercedes-Benz AMG GLA35              6450000        2000    Petrol
# 394     Jeep Wrangler Rubicon              6500000       27340    Petrol
# 426          Land Rover Range              7700000       39800    Petrol
# 566        Audi Q7 Technology              9300000        6500    Petrol
# ...

# %% [markdown]
# to check the cars that cost more than 60 lakh

# %%
car[car['car_price_in_rupees']<6e6].reset_index(drop=True)
# Out:
#                     car_name  car_price_in_rupees  kms_driven fuel_type  \
# 0          Hyundai Grand i10               445000       22402    Petrol
# 1         Maruti Suzuki Alto               293000       10344    Petrol
# 2             Tata Safari XZ              2249000       12999    Diesel
# 3         Maruti Suzuki Ciaz               695000       45000    Petrol
# 4         Jeep Compass Sport              1200000       11193    Petrol
# ...                      ...                  ...         ...       ...
# 2069   Ford Figo Titanium1.5               360000       42158    Diesel
# 2070  MINI Cooper Countryman              2200000       68862    Diesel
# 2071       Hyundai Verna 1.6               838000       37622    Petrol
# 2072      Maruti Suzuki Ciaz               675000       64726    Petrol
# 2073       Hyundai Verna 1.6               876000       29150    Petrol
#
#            city  year_of_manufacture
# 0        Mumbai                 2016
# ...

# %% [markdown]
# to check the cars that cost less than 60 lakh

# %%
car.to_csv('Cleaned Car.csv')

# %% [markdown]
# **MODEL**

# %%
X=car.drop(columns='car_price_in_rupees')
y=car['car_price_in_rupees']

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.2)

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score
from sklearn.preprocessing import OneHotEncoder
from sklearn.compose import make_column_transformer
from sklearn.pipeline import make_pipeline

# %%
ohe=OneHotEncoder()
ohe.fit(X[['car_name','city','fuel_type']])
# Out:
# OneHotEncoder()

# %%
column_trans=make_column_transformer((OneHotEncoder(categories=ohe.categories_,handle_unknown='ignore'),['car_name','city','fuel_type']),remainder='passthrough')

# %%
lr=LinearRegression()

# %%
pipe=make_pipeline(column_trans,lr)

# %%
pipe.fit(X_train,y_train)
# Out:
# Pipeline(steps=[('columntransformer',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('onehotencoder',
#                                                   OneHotEncoder(categories=[array(['Audi A3 35', 'Audi A3 40', 'Audi A4 2.0', 'Audi A4 3.0',
#        'Audi A4 35', 'Audi A4 Technology', 'Audi A6 2.0', 'Audi A6 35',
#        'Audi A6 Technology', 'Audi A8 L', 'Audi Q2 Premium',
#        'Audi Q3 2.0', 'Audi Q3 30', 'Audi Q3 35', 'Audi Q5 2.0',
#        'Audi Q5 3.0', 'Audi...
#                                                                             array(['Ahmedabad', 'Ambattur', 'Bangalore', 'Chennai', 'Delhi',
#        'Faridabad', 'Gurgaon', 'Hyderabad', 'Kolkata', 'Mumbai', 'Noida',
#        'Pallikarnai', 'Poonamallee', 'Pune', 'Thane', 'Thiruvallur'],
#       dtype=object),
# ...

# %%
# Assuming 'pipe' is your pipeline, and X_train, y_train are your training data
pipe.fit(X_train, y_train)

# Now you can use the predict method
y_pred = pipe.predict(X_test)

# %%
r2_score(y_test,y_pred)
# Out:
# 0.21855488110008325

# %%
scores=[]
for i in range(1000):
  X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.2,random_state=i)
  lr=LinearRegression()
  pipe=make_pipeline(column_trans,lr)
  pipe.fit(X_train,y_train)
  y_pred=pipe.predict(X_test)

  scores.append(r2_score(y_test,y_pred))

# %%
np.argmax(scores)
# Out:
# 797

# %%
scores[np.argmax(scores)]
# Out:
# 0.5452377778849696

# %%
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.2,random_state=np.argmax(scores))
lr=LinearRegression()
pipe=make_pipeline(column_trans,lr)
pipe.fit(X_train,y_train)
y_pred=pipe.predict(X_test)
r2_score(y_test,y_pred)
# Out:
# 0.5452377778849696

# %%
import pickle

# %%
pickle.dump(pipe,open('LinearRegressionModel.pkl','wb'))

# %%
pipe.predict(pd.DataFrame([['Maruti Suzuki Swift', 100, 'Petrol', 'Thane', 2019]], columns=['car_name', 'kms_driven', 'fuel_type', 'city', 'year_of_manufacture']))
# Out:
# array([505175.30158076])
